# %% [markdown]
# # TCO RAG Comparison (Colab)
#
# This notebook runs the ontology-augmented RAG experiment using **Google Gemini** via `google-generativeai`.
# It satisfies the rubric by: (1) programmatically querying an ontology (BioPortal/TCO) and (2) using ontology-augmented RAG.
#
# If you get a `requirements.txt not found` error, upload the project folder (or mount Google Drive) so the notebook can see the repo files.

# %%
# Optional: mount Google Drive if your repo is there
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1476315615.py in <cell line: 0>()
#       1 # Optional: mount Google Drive if your repo is there
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %%
# Install dependencies
import os
req_path = os.path.join(os.getcwd(), 'requirements.txt')
# !pip -q install -r {req_path} python-dotenv

# %% [markdown]
# ## Set API Keys
# Upload your `.env` file or set the keys manually.
# Required: `GOOGLE_API_KEY` (Gemini)
# Optional: `BIOPORTAL_API_KEY` (higher BioPortal rate limits)

# %%
# Option A: Upload .env from your local machine
# from google.colab import files
# uploaded = files.upload()  # upload .env

import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Force Gemini (not Hugging Face)
os.environ['USE_HUGGINGFACE'] = 'true'

# %% [markdown]
# ## Run Experiment
# This runs `rag_exp.py` end-to-end and saves artifacts:
# - `synthetic_charts.csv`
# - `tco_corpus.jsonl`
# - `results.json`
# - `examples.md`
# - `llm_cache.json`

# %%
# !python rag_exp.py
# Out:
# /Users/cindyz1/bime/550/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ...
# Ontology-Grounded RAG for Thyroid Cancer Diagnosis
# ...
# Random seed: 42
# BioPortal API key: Found
# OpenAI API key: Not found
# Use Hugging Face: true
#
#
# ...
# Connecting to BioPortal
# ...
# ✓ Successfully connected to BioPortal
#   Ontology: Thyroid Cancer Ontology
#   Acronym: TCO
#   Version: 1.0
#   Released: 2020-07-02T00:00:00.000+00:00
#
# ...
# Building TCO Retrieval Corpus
# ...
# ✓ Loaded cached corpus from tco_corpus.jsonl (8 classes)
#
# ...
# Generating Synthetic Patient Charts
# ...
# Traceback (most recent call last):
#   File "/Users/cindyz1/bime/550/rag_exp.py", line 615, in <module>
#     main()
#   File "/Users/cindyz1/bime/550/rag_exp.py", line 405, in main
#     domain_spec = DOMAIN_SPECS["tco_thyroid"]
# ...

# %% [markdown]
# ## Quick Results Preview

# %%
import json
with open('results.json', 'r') as f:
    results = json.load(f)

results['metrics']
